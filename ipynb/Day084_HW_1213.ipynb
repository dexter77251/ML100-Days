# %% [markdown]
# ## Work
# ### 請結合前面的知識與程式碼，比較不同的 regularization 的組合對訓練的結果與影響：如 dropout, regularizers, batch-normalization 等

# %%
import os
import keras
import itertools
# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""
# Out:
# Using TensorFlow backend.

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.models import Sequential
from keras.layers import Dense,Dropout,BatchNormalization
from keras.regularizers import l1
import matplotlib.pyplot as plt
from keras import optimizers

# %%
# Hint 1 : 在 Dense 層中增加 Regularizers
# Hint 2 : 增加 Dropout 層並設定 dropout ratio 
# Hint 3 : 增加 Batch-normalization 層
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128],Regu_rate=1e-4,drp_ratio=0.2):
    
    model = Sequential()
    model.add(Dense(units = input_shape[1] ,input_dim = input_shape[1], kernel_initializer = 'normal', activation = 'relu',name = 'input'))
    
    for i, n_units in enumerate(num_neurons):
        model.add(Dense(units=n_units, kernel_initializer='normal', activation='relu',name="hidden_layer"+str(i+1), kernel_regularizer=l1(Regu_rate)))  
        model.add(Dropout(drp_ratio))  
        model.add(BatchNormalization())         
    
    model.add(Dense(units=output_units,kernel_initializer='normal', activation='softmax',name='output'))

    return model

# %%
def plot_model_score(results):
    
    NUM_COLORS = len(results.keys())
    cm = plt.get_cmap('gist_rainbow')
    color_bar = [cm(1.*i/NUM_COLORS) for i in range(NUM_COLORS)]
    
    plt.figure(figsize=(10,8))
    for i, cond in enumerate(results.keys()):
        plt.plot(range(len(results[cond]['train-loss'])),results[cond]['train-loss'], '-', label='train-'+cond, color=color_bar[i])
        plt.plot(range(len(results[cond]['valid-loss'])),results[cond]['valid-loss'], '--', label='valid-'+cond, color=color_bar[i])
    plt.title("Loss")
    
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.show()


    plt.figure(figsize=(10,8))
    for i, cond in enumerate(results.keys()):
        plt.plot(range(len(results[cond]['train-acc'])),results[cond]['train-acc'], '-', label='train-'+cond, color=color_bar[i])
        plt.plot(range(len(results[cond]['valid-acc'])),results[cond]['valid-acc'], '--', label='valid-'+cond, color=color_bar[i])
    plt.title("Accuracy")
    
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.show()

# %%
"""Code Here
設定超參數
"""
LEARNING_RATE = 0.01
EPOCHS = 6
BATCH_SIZE = [100,300]
MOMENTUM = 0.95
L1_EXP = [0.001, 0.005, 0.05]
Dropout_EXP = [0.2,0.5]

# %%
"""Code Here
撰寫你的訓練流程並將結果用 dictionary 紀錄
"""
results = {}

for regu_rate,drop_rate,batch_size in itertools.product(L1_EXP,Dropout_EXP,BATCH_SIZE):
    keras.backend.clear_session() # 把舊的 Graph 清掉
    model = build_mlp(input_shape=x_train.shape,Regu_rate=regu_rate,drp_ratio=drop_rate)
    model.summary()
    optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
    model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

    model.fit(x_train, y_train, 
              epochs=EPOCHS, 
              batch_size=batch_size, 
              validation_data=(x_test, y_test), 
              shuffle=True)

    # Collect results
    train_loss = model.history.history["loss"]
    valid_loss = model.history.history["val_loss"]
    train_acc = model.history.history["accuracy"]
    valid_acc = model.history.history["val_accuracy"]
    
    exp_name_tag = f'L1:{str(regu_rate)},DR: {str(drop_rate)},BS:{str(batch_size)}'
    results[exp_name_tag] = {'train-loss': train_loss,
                             'valid-loss': valid_loss,
                             'train-acc': train_acc,
                             'valid-acc': valid_acc}
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (Dense)                (None, 3072)              9440256
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 11,182,730
# Trainable params: 11,180,938
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/6
# 50000/50000 [==============================] - 59s 1ms/step - loss: 26.5882 - accuracy: 0.2924 - val_loss: 5.2798 - val_accuracy: 0.1664
# Epoch 2/6
# 50000/50000 [==============================] - 52s 1ms/step - loss: 3.2801 - accuracy: 0.3532 - val_loss: 2.6016 - val_accuracy: 0.3725
# Epoch 3/6
# 50000/50000 [==============================] - 52s 1ms/step - loss: 2.4156 - accuracy: 0.3632 - val_loss: 2.2428 - val_accuracy: 0.3757
# Epoch 4/6
# 50000/50000 [==============================] - 57s 1ms/step - loss: 2.2179 - accuracy: 0.3694 - val_loss: 2.1007 - val_accuracy: 0.3957
# Epoch 5/6
# 50000/50000 [==============================] - 52s 1ms/step - loss: 2.1023 - accuracy: 0.3821 - val_loss: 2.0309 - val_accuracy: 0.4049
# Epoch 6/6
# 50000/50000 [==============================] - 52s 1ms/step - loss: 2.0355 - accuracy: 0.3957 - val_loss: 2.0011 - val_accuracy: 0.3947
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (Dense)                (None, 3072)              9440256
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 11,182,730
# Trainable params: 11,180,938
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/6
# 50000/50000 [==============================] - 28s 552us/step - loss: 51.5807 - accuracy: 0.3207 - val_loss: 31.7229 - val_accuracy: 0.3481
# Epoch 2/6
# 50000/50000 [==============================] - 25s 495us/step - loss: 19.6055 - accuracy: 0.3822 - val_loss: 11.2887 - val_accuracy: 0.2697
# Epoch 3/6
# 50000/50000 [==============================] - 24s 489us/step - loss: 7.0237 - accuracy: 0.3921 - val_loss: 4.6702 - val_accuracy: 0.3499
# Epoch 4/6
# 50000/50000 [==============================] - 52s 1ms/step - loss: 42.7009 - accuracy: 0.1808 - val_loss: 42.5550 - val_accuracy: 0.1304
# Epoch 5/6
# 50000/50000 [==============================] - 51s 1ms/step - loss: 42.4539 - accuracy: 0.1708 - val_loss: 42.3935 - val_accuracy: 0.1556
# Epoch 6/6
# 50000/50000 [==============================] - 55s 1ms/step - loss: 42.3243 - accuracy: 0.1670 - val_loss: 42.3914 - val_accuracy: 0.1489
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (Dense)                (None, 3072)              9440256
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 11,182,730
# Trainable params: 11,180,938
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/6
# 50000/50000 [==============================] - 26s 524us/step - loss: 343.9723 - accuracy: 0.1707 - val_loss: 46.8312 - val_accuracy: 0.1000
# Epoch 2/6
# 50000/50000 [==============================] - 25s 505us/step - loss: 45.0847 - accuracy: 0.1800 - val_loss: 44.3934 - val_accuracy: 0.1248
# Epoch 3/6
# 50000/50000 [==============================] - 31s 627us/step - loss: 43.6797 - accuracy: 0.1927 - val_loss: 43.1768 - val_accuracy: 0.1498
# Epoch 4/6
# 50000/50000 [==============================] - 26s 510us/step - loss: 43.0896 - accuracy: 0.2039 - val_loss: 43.2029 - val_accuracy: 0.1780
# Epoch 5/6
# 50000/50000 [==============================] - 24s 486us/step - loss: 42.6779 - accuracy: 0.2188 - val_loss: 42.6327 - val_accuracy: 0.2144
# Epoch 6/6
# 50000/50000 [==============================] - 24s 486us/step - loss: 42.4770 - accuracy: 0.2201 - val_loss: 42.6435 - val_accuracy: 0.2276
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (Dense)                (None, 3072)              9440256
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 11,182,730
# Trainable params: 11,180,938
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/6
# 50000/50000 [==============================] - 55s 1ms/step - loss: 149.4921 - accuracy: 0.1414 - val_loss: 47.8994 - val_accuracy: 0.1567
# Epoch 2/6
# 50000/50000 [==============================] - 51s 1ms/step - loss: 45.0808 - accuracy: 0.1607 - val_loss: 43.3058 - val_accuracy: 0.1812
# Epoch 3/6
# 50000/50000 [==============================] - 64s 1ms/step - loss: 43.1280 - accuracy: 0.1576 - val_loss: 42.5099 - val_accuracy: 0.1855
# Epoch 4/6
# 50000/50000 [==============================] - 58s 1ms/step - loss: 42.6059 - accuracy: 0.1434 - val_loss: 42.8324 - val_accuracy: 0.1752
# Epoch 5/6
# 50000/50000 [==============================] - 49s 979us/step - loss: 42.4234 - accuracy: 0.1157 - val_loss: 42.3049 - val_accuracy: 0.1000
# Epoch 6/6
# 50000/50000 [==============================] - 52s 1ms/step - loss: 42.3112 - accuracy: 0.0975 - val_loss: 42.3212 - val_accuracy: 0.1000
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (Dense)                (None, 3072)              9440256
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 11,182,730
# Trainable params: 11,180,938
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/6
# 50000/50000 [==============================] - 31s 622us/step - loss: 343.4335 - accuracy: 0.1415 - val_loss: 47.9835 - val_accuracy: 0.1000
# Epoch 2/6
# 50000/50000 [==============================] - 28s 559us/step - loss: 45.3617 - accuracy: 0.1620 - val_loss: 45.1348 - val_accuracy: 0.1299
# Epoch 3/6
# 50000/50000 [==============================] - 29s 578us/step - loss: 43.8926 - accuracy: 0.1719 - val_loss: 43.4348 - val_accuracy: 0.1535
# Epoch 4/6
# 50000/50000 [==============================] - 27s 544us/step - loss: 43.1833 - accuracy: 0.1720 - val_loss: 43.0117 - val_accuracy: 0.1881
# Epoch 5/6
# 50000/50000 [==============================] - 24s 482us/step - loss: 42.7479 - accuracy: 0.1721 - val_loss: 42.6494 - val_accuracy: 0.1843
# Epoch 6/6
# 50000/50000 [==============================] - 24s 484us/step - loss: 42.5535 - accuracy: 0.1688 - val_loss: 42.3655 - val_accuracy: 0.1852

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
"""Code Here
將結果繪出
"""
plot_model_score(results)
